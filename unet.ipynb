# %% [markdown]
# <a href="https://colab.research.google.com/github/ifarady/attention-in-seismic/blob/main/unet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Import Necessary Libraries
import os
import time
import math
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision
import torchvision.transforms as T
import matplotlib.cm as cm

# %%
# Step 2: Define Utility Functions
def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

# %%
#Set Device and Model Path
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

model_path = 'unet_model.pth'
# Out:
# cuda

# %%
#Specify Paths and Configuration

image_path = "competition_data/train/images"
mask_path = "competition_data/train/masks"
val_image_path = "competition_data/val/images"
val_mask_path = "competition_data/val/masks"

# %%
#Load and Preprocess Data for Visualization
names = ['4c4556fff0','4c8132dc73','4c36178b41']
images = [Image.open(os.path.join(image_path, name+'.png')) for name in names]
masks = [Image.open(os.path.join(mask_path, name+'.png')) for name in names]

transforms = T.Compose([T.Grayscale(), T.ToTensor()])
x = torch.stack([transforms(image) for image in images])
y = torch.stack([transforms(mask) for mask in masks])

# %%
# Step 6: Visualize Sample Data
fig = plt.figure(figsize=(9, 9))
num_images = len(images)
for i in range(num_images):
    ax = fig.add_subplot(num_images, 3, i*3+1)
    ax.imshow(images[i])
    ax.set_title("Original Image")

    ax = fig.add_subplot(num_images, 3, i*3+2)
    ax.imshow(masks[i])
    ax.set_title("Mask")

    ax = fig.add_subplot(num_images, 3, i*3+3)
    ax.imshow(x[i].squeeze(), cmap="Greys")
    ax.imshow(y[i].squeeze(), alpha=0.5, cmap="Greens")
    ax.set_title("Image with Mask")

plt.show()

# %%
# Step 7: Define Custom Dataset Class
class segmentDataset(Dataset):
    def __init__(self, image_path, mask_path):
        self.image_path = image_path
        self.mask_path = mask_path

        image_list = glob.glob(image_path + '/*.png')
        sample_names = [file.split('/')[-1].split('.')[0] for file in image_list]
        self.sample_names = sample_names
        self.transforms = T.Compose([T.Grayscale(), T.ToTensor()])

    def __getitem__(self, idx):
        image = Image.open(os.path.join(self.image_path, self.sample_names[idx] + '.png'))
        mask = Image.open(os.path.join(self.mask_path, self.sample_names[idx] + '.png'))
        return self.transforms(image), self.transforms(mask)

    def __len__(self):
        return len(self.sample_names)

# %%
# Step 8: Initialize Dataset
train_dataset = segmentDataset(image_path, mask_path)
# Step 5: Validation Dataset
val_dataset = segmentDataset(val_image_path, val_mask_path)

# %%
# # Step 6: Validation DataLoader
BATCH_SIZE = 64
val_dataloader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
# Step 9: Visualize More Data from Dataset
max_images = 16
grid_width = 8
grid_height = max_images // grid_width
fig, axs = plt.subplots(grid_height, grid_width, figsize=(grid_width * 2, grid_height * 2))

for i in range(max_images):
    image, mask = train_dataset[i]
    ax = axs[i // grid_width, i % grid_width]
    ax.imshow(image.squeeze(), cmap="Greys")
    ax.imshow(mask.squeeze(), alpha=0.5, cmap="Greens")
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.set_title(f"Sample {i+1}", fontsize=10)

# # Add color bar to indicate mask colors
# cax = fig.add_axes([0.92, 0.1, 0.02, 0.8])
# cbar = plt.colorbar(cm.ScalarMappable(cmap='Greens'), cax=cax)
# cbar.set_label('Mask Colors')

plt.show()

# %%
# Step 10: Define Model Architecture

"""
This class defines a convolutional block, which consists of a convolutional layer followed by batch normalization.
"""
class ConvBlock(nn.Module):
    def __init__(self, in_channels, filters, size, stride=1, activation=True):
        super(ConvBlock, self).__init__()
        self.activation = activation
        # Convolutional layer with specified parameters
        self.conv = nn.Conv2d(in_channels, filters, size, stride=stride, padding=size // 2)
        # Batch normalization layer
        self.norm = nn.BatchNorm2d(filters)

    def forward(self, x):
        # Forward pass through the convolutional block
        x = self.conv(x)  # Apply convolution
        x = self.norm(x)  # Apply batch normalization
        if self.activation:
            return F.relu(x)  # Apply ReLU activation if specified
        else:
            return x


"""
This class defines a residual block, which consists of two convolutional blocks and optional residual connections.
"""
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, filters, size=3):
        super(ResidualBlock, self).__init__()
        self.norm = nn.BatchNorm2d(in_channels)
        # First convolutional block
        self.conv1 = ConvBlock(in_channels, filters, size)
        # Second convolutional block with no activation
        self.conv2 = ConvBlock(filters, filters, size, activation=False)

    def forward(self, x):
        residual = x  # Save input as residual
        x = F.relu(x)  # Apply ReLU activation
        x = self.norm(x)  # Apply batch normalization
        x = self.conv1(x)  # First convolutional block
        x = self.conv2(x)  # Second convolutional block
        # Optionally add residual connection
        # x += residual  # Uncomment if you want to use residual connections
        return x


"""
This class defines a deconvolutional block, which consists of a transposed convolutional layer.
"""
class DeconvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=2, stride=2):
        super(DeconvBlock, self).__init__()
        # Transposed convolutional layer
        self.deconv = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=kernel_size, stride=stride)

    def forward(self, x1, x2):
        xd = self.deconv(x1)  # Apply transposed convolution
        # Concatenate feature maps from the transposed convolution with feature maps from a previous stage
        x = torch.cat([xd, x2], dim=1)
        return x

# %%
# Step 11: Define U-Net Model
class UnetModel(nn.Module):

    def __init__(self, filters=16, dropout=0.5):
        super(UnetModel, self).__init__()
        # Define encoder layers
        self.conv1 = nn.Sequential(
            nn.Conv2d(1, filters, 3, padding=1),
            ResidualBlock(filters, filters),
            ResidualBlock(filters, filters),
            nn.ReLU()
        )
        self.conv2 = nn.Sequential(
            nn.MaxPool2d(2, 2),
            nn.Dropout(dropout/2),
            nn.Conv2d(filters, filters * 2, 3, padding=1),
            ResidualBlock(filters * 2, filters * 2),
            ResidualBlock(filters * 2, filters * 2),
            nn.ReLU()
        )
        self.conv3 = nn.Sequential(
            nn.MaxPool2d(2, 2),
            nn.Dropout(dropout),
            nn.Conv2d(filters * 2, filters * 4, 3, padding=1),
            ResidualBlock(filters * 4, filters * 4),
            ResidualBlock(filters * 4, filters * 4),
            nn.ReLU()
        )
        self.conv4 = nn.Sequential(
            nn.MaxPool2d(2, 2),
            nn.Dropout(dropout),
            nn.Conv2d(filters * 4, filters * 8, 3, padding=1),
            ResidualBlock(filters * 8, filters * 8),
            ResidualBlock(filters * 8, filters * 8),
            nn.ReLU()
        )
        # Define middle layers
        self.middle = nn.Sequential(
            nn.MaxPool2d(2, 2),
            nn.Dropout(dropout),
            nn.Conv2d(filters * 8, filters * 16, 3, padding=3//2),
            ResidualBlock(filters * 16, filters * 16),
            ResidualBlock(filters * 16, filters * 16),
            nn.ReLU()
        )
        # Define decoder layers
        self.deconv4 = DeconvBlock(filters * 16, filters * 8, 2)
        self.upconv4 = nn.Sequential(
            nn.Dropout(dropout),
            nn.Conv2d(filters * 16, filters * 8, 3, padding=1),
            ResidualBlock(filters * 8, filters * 8),
            ResidualBlock(filters * 8, filters * 8),
            nn.ReLU()
        )
        self.deconv3 = DeconvBlock(filters * 8, filters * 4, 3)
        self.upconv3 = nn.Sequential(
            nn.Dropout(dropout),
            nn.Conv2d(filters * 8, filters * 4, 3, padding=1),
            ResidualBlock(filters * 4, filters * 4),
            ResidualBlock(filters * 4, filters * 4),
            nn.ReLU()
        )
        self.deconv2 = DeconvBlock(filters * 4, filters * 2, 2)
        self.upconv2 = nn.Sequential(
            nn.Dropout(dropout),
            nn.Conv2d(filters * 4, filters * 2, 3, padding=1),
            ResidualBlock(filters * 2, filters * 2),
            ResidualBlock(filters * 2, filters * 2),
            nn.ReLU()
        )
        self.deconv1 = DeconvBlock(filters * 2, filters, 3)
        self.upconv1 = nn.Sequential(
            nn.Dropout(dropout),
            nn.Conv2d(filters * 2, filters, 3, padding=1),
            ResidualBlock(filters, filters),
            ResidualBlock(filters, filters),
            nn.ReLU(),
            nn.Dropout(dropout/2),
            nn.Conv2d(filters, 1, 3, padding=1)
        )

    def forward(self, x):
        conv1 = self.conv1(x)
        conv2 = self.conv2(conv1)
        conv3 = self.conv3(conv2)
        conv4 = self.conv4(conv3)
        x = self.middle(conv4)
        x = self.deconv4(x, conv4)
        x = self.upconv4(x)
        x = self.deconv3(x, conv3)
        x = self.upconv3(x)
        x = self.deconv2(x, conv2)
        x = self.upconv2(x)
        x = self.deconv1(x, conv1)
        x = self.upconv1(x)
        return x

# %%
# Step 13: Training Function
def train_one_batch(model, x, y, optimizer, loss_fn):
    x, y = x.to(device), y.to(device)

    outputs = model(x)
    loss = loss_fn(outputs, y)
    iou = get_iou_score(outputs, y).mean()

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    return loss.item(), iou.item()

# %%
# Step 14: Validation Function
def validate_one_batch(model, x, y, loss_fn):
    x, y = x.to(device), y.to(device)

    outputs = model(x)
    loss = loss_fn(outputs, y)
    iou = get_iou_score(outputs, y).mean()

    return loss.item(), iou.item()

# %%
# Step 14: Set Training Hyperparameters
NUM_EPOCHS = 200
BATCH_SIZE = 64

# %%
# Step 15: Initialize Model, Optimizer, and Loss Function
model = UnetModel().to(device)
model.train()
optimizer = torch.optim.Adam(model.parameters())
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'max')
loss_fn = nn.BCEWithLogitsLoss()

# %%
# Step 15: Get IoU Score
def get_iou_score(outputs, labels):
    A = labels.squeeze().bool()
    pred = torch.where(outputs < 0., torch.zeros_like(outputs), torch.ones_like(outputs))
    B = pred.squeeze().bool()
    intersection = (A & B).float().sum((1, 2))
    union = (A | B).float().sum((1, 2))
    iou = (intersection + 1e-6) / (union + 1e-6)
    return iou

# %%
# Step 16: Create DataLoader for Training Dataset
train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)
steps = len(train_dataset) // BATCH_SIZE
print(steps, "steps per epoch")
# Out:
# 56 steps per epoch

# %%
# Step 16: Model Training

model = UnetModel().to(device)
optimizer = torch.optim.Adam(model.parameters())
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'max')
loss_fn = nn.BCEWithLogitsLoss()

train_dataset = segmentDataset(image_path, mask_path)
train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

train_losses = []
train_ious = []
val_losses = []
val_ious = []

max_val_iou = -1
best_epoch_loss = -1
best_epoch = -1

start = time.time()
for epoch in range(1, NUM_EPOCHS + 1):
    print('-' * 10)
    print('Epoch {}/{}'.format(epoch, NUM_EPOCHS))

    running_train_loss = []
    running_train_iou = []
    running_val_loss = []
    running_val_iou = []

    # Training Phase
    model.train()
    for step, (x_train, y_train) in enumerate(train_dataloader):
        train_loss, train_iou = train_one_batch(model, x_train, y_train, optimizer, loss_fn)
        running_train_loss.append(train_loss)
        running_train_iou.append(train_iou)
        print('\rTraining | Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, IoU: {:.4f}'.format(
            epoch, NUM_EPOCHS, step+1, len(train_dataloader), train_loss, train_iou), end="")

    # Validation Phase
    model.eval()
    with torch.no_grad():
        for x_val, y_val in val_dataloader:
            val_loss, val_iou = validate_one_batch(model, x_val, y_val, loss_fn)
            running_val_loss.append(val_loss)
            running_val_iou.append(val_iou)

    # Compute average metrics for the epoch
    avg_train_loss = sum(running_train_loss) / len(running_train_loss)
    avg_train_iou = sum(running_train_iou) / len(running_train_iou)
    avg_val_loss = sum(running_val_loss) / len(running_val_loss)
    avg_val_iou = sum(running_val_iou) / len(running_val_iou)

    # Append to lists for plotting
    train_losses.append(avg_train_loss)
    train_ious.append(avg_train_iou)
    val_losses.append(avg_val_loss)
    val_ious.append(avg_val_iou)

    # Print epoch summary
    print('\rTraining | Epoch [{}/{}], Avg Loss: {:.4f}, Avg IoU: {:.4f}'.format(
        epoch, NUM_EPOCHS, avg_train_loss, avg_train_iou))
    print('\rValidation | Epoch [{}/{}], Avg Loss: {:.4f}, Avg IoU: {:.4f}'.format(
        epoch, NUM_EPOCHS, avg_val_loss, avg_val_iou))

    # Adjust learning rate based on validation IoU
    scheduler.step(avg_val_iou)

    if avg_val_iou > max_val_iou:
        best_epoch = epoch
        max_val_iou = avg_val_iou
        best_epoch_loss = avg_val_loss
        print('\rSave best model with mIoU = {}'.format(avg_val_iou))
        torch.save(model.state_dict(), 'best_model.pth')
    else:
        print('\rBest mIoU: {} at epoch {}'.format(max_val_iou, best_epoch))
# Out:
# ----------
# Epoch 1/200
# Training | Epoch [1/200], Avg Loss: 0.4303, Avg IoU: 0.36140.5003
# Validation | Epoch [1/200], Avg Loss: 1.2896, Avg IoU: 0.3016
# Save best model with mIoU = 0.30161231756210327
# ----------
# Epoch 2/200
# Training | Epoch [2/200], Avg Loss: 0.3035, Avg IoU: 0.56040.5686
# Validation | Epoch [2/200], Avg Loss: 0.3552, Avg IoU: 0.5305
# Save best model with mIoU = 0.5305469376700265
# ----------
# Epoch 3/200
# Training | Epoch [3/200], Avg Loss: 0.2659, Avg IoU: 0.58500.6067
# Validation | Epoch [3/200], Avg Loss: 0.2883, Avg IoU: 0.5435
# Save best model with mIoU = 0.5435000317437308
# ----------
# Epoch 4/200
# Training | Epoch [4/200], Avg Loss: 0.2599, Avg IoU: 0.60790.3478
# Validation | Epoch [4/200], Avg Loss: 0.3029, Avg IoU: 0.5430
# Best mIoU: 0.5435000317437308 at epoch 3
# ----------
# Epoch 5/200
# Training | Epoch [5/200], Avg Loss: 0.2597, Avg IoU: 0.60630.4679
# Validation | Epoch [5/200], Avg Loss: 0.2180, Avg IoU: 0.6174
# Save best model with mIoU = 0.6174073815345764
# ----------
# Epoch 6/200
# Training | Epoch [6/200], Avg Loss: 0.2313, Avg IoU: 0.64000.6356
# Validation | Epoch [6/200], Avg Loss: 0.1956, Avg IoU: 0.6320
# Save best model with mIoU = 0.63202075447355
# ----------
# Epoch 7/200
# Training | Epoch [7/200], Avg Loss: 0.2192, Avg IoU: 0.63770.4775
# Validation | Epoch [7/200], Avg Loss: 0.2562, Avg IoU: 0.5852
# Best mIoU: 0.63202075447355 at epoch 6
# ----------
# Epoch 8/200
# Training | Epoch [8/200], Avg Loss: 0.2283, Avg IoU: 0.64670.6451
# Validation | Epoch [8/200], Avg Loss: 0.3376, Avg IoU: 0.5106
# Best mIoU: 0.63202075447355 at epoch 6
# ----------
# Epoch 9/200
# Training | Epoch [9/200], Avg Loss: 0.2263, Avg IoU: 0.62260.5095
# Validation | Epoch [9/200], Avg Loss: 0.1945, Avg IoU: 0.6215
# Best mIoU: 0.63202075447355 at epoch 6
# ----------
# Epoch 10/200
# Training | Epoch [10/200], Avg Loss: 0.2091, Avg IoU: 0.64890.6290
# Validation | Epoch [10/200], Avg Loss: 0.2223, Avg IoU: 0.6182
# Best mIoU: 0.63202075447355 at epoch 6
# ----------
# Epoch 11/200
# Training | Epoch [11/200], Avg Loss: 0.2025, Avg IoU: 0.65660.5838
# Validation | Epoch [11/200], Avg Loss: 0.2128, Avg IoU: 0.6487
# Save best model with mIoU = 0.6486689533506121
# ----------
# Epoch 12/200
# Training | Epoch [12/200], Avg Loss: 0.1962, Avg IoU: 0.67760.8207
# Validation | Epoch [12/200], Avg Loss: 0.2547, Avg IoU: 0.6246
# Best mIoU: 0.6486689533506121 at epoch 11
# ----------
# Epoch 13/200
# Training | Epoch [13/200], Avg Loss: 0.1881, Avg IoU: 0.67680.6717
# Validation | Epoch [13/200], Avg Loss: 0.2026, Avg IoU: 0.6618
# Save best model with mIoU = 0.6618372116770063
# ----------
# Epoch 14/200
# Training | Epoch [14/200], Avg Loss: 0.1890, Avg IoU: 0.68030.6191
# Validation | Epoch [14/200], Avg Loss: 0.2564, Avg IoU: 0.6086
# Best mIoU: 0.6618372116770063 at epoch 13
# ----------
# Epoch 15/200
# Training | Epoch [15/200], Avg Loss: 0.1795, Avg IoU: 0.68740.5797
# Validation | Epoch [15/200], Avg Loss: 0.1975, Avg IoU: 0.6446
# Best mIoU: 0.6618372116770063 at epoch 13
# ----------
# Epoch 16/200
# Training | Epoch [16/200], Avg Loss: 0.1855, Avg IoU: 0.69950.8364
# Validation | Epoch [16/200], Avg Loss: 0.1956, Avg IoU: 0.6584
# Best mIoU: 0.6618372116770063 at epoch 13
# ----------
# Epoch 17/200
# Training | Epoch [17/200], Avg Loss: 0.1761, Avg IoU: 0.70130.5701
# Validation | Epoch [17/200], Avg Loss: 0.2619, Avg IoU: 0.6348
# Best mIoU: 0.6618372116770063 at epoch 13
# ----------
# Epoch 18/200
# Training | Epoch [18/200], Avg Loss: 0.1839, Avg IoU: 0.69040.5615
# Validation | Epoch [18/200], Avg Loss: 0.1747, Avg IoU: 0.6926
# Save best model with mIoU = 0.6926497391292027
# ----------
# Epoch 19/200
# Training | Epoch [19/200], Avg Loss: 0.1808, Avg IoU: 0.68650.6895
# Validation | Epoch [19/200], Avg Loss: 0.1738, Avg IoU: 0.6851
# Best mIoU: 0.6926497391292027 at epoch 18
# ----------
# Epoch 20/200
# Training | Epoch [20/200], Avg Loss: 0.1744, Avg IoU: 0.69320.7326
# Validation | Epoch [20/200], Avg Loss: 0.1808, Avg IoU: 0.6426
# Best mIoU: 0.6926497391292027 at epoch 18
# ----------
# Epoch 21/200
# Training | Epoch [21/200], Avg Loss: 0.1655, Avg IoU: 0.70510.4665
# Validation | Epoch [21/200], Avg Loss: 0.1785, Avg IoU: 0.6685
# Best mIoU: 0.6926497391292027 at epoch 18
# ----------
# Epoch 22/200
# Training | Epoch [22/200], Avg Loss: 0.1673, Avg IoU: 0.69880.4935
# Validation | Epoch [22/200], Avg Loss: 0.1661, Avg IoU: 0.6791
# Best mIoU: 0.6926497391292027 at epoch 18
# ----------
# Epoch 23/200
# Training | Epoch [23/200], Avg Loss: 0.1634, Avg IoU: 0.71330.5947
# Validation | Epoch [23/200], Avg Loss: 0.1613, Avg IoU: 0.7078
# Save best model with mIoU = 0.7077745710100446
# ----------
# Epoch 24/200
# Training | Epoch [24/200], Avg Loss: 0.1612, Avg IoU: 0.71910.6984
# Validation | Epoch [24/200], Avg Loss: 0.2146, Avg IoU: 0.6494
# Best mIoU: 0.7077745710100446 at epoch 23
# ----------
# Epoch 25/200
# Training | Epoch [25/200], Avg Loss: 0.1817, Avg IoU: 0.69040.7594
# Validation | Epoch [25/200], Avg Loss: 0.1643, Avg IoU: 0.7115
# Save best model with mIoU = 0.7114887748445783
# ----------
# Epoch 26/200
# Training | Epoch [26/200], Avg Loss: 0.1992, Avg IoU: 0.67690.7421
# Validation | Epoch [26/200], Avg Loss: 0.1744, Avg IoU: 0.6784
# Best mIoU: 0.7114887748445783 at epoch 25
# ----------
# Epoch 27/200
# Training | Epoch [27/200], Avg Loss: 0.1805, Avg IoU: 0.69290.5250
# Validation | Epoch [27/200], Avg Loss: 0.1463, Avg IoU: 0.6980
# Best mIoU: 0.7114887748445783 at epoch 25
# ----------
# Epoch 28/200
# Training | Epoch [28/200], Avg Loss: 0.1726, Avg IoU: 0.69690.5323
# Validation | Epoch [28/200], Avg Loss: 0.1521, Avg IoU: 0.6967
# Best mIoU: 0.7114887748445783 at epoch 25
# ----------
# Epoch 29/200
# Training | Epoch [29/200], Avg Loss: 0.1698, Avg IoU: 0.70080.6079
# Validation | Epoch [29/200], Avg Loss: 0.1523, Avg IoU: 0.7127
# Save best model with mIoU = 0.712713531085423
# ----------
# Epoch 30/200
# Training | Epoch [30/200], Avg Loss: 0.1653, Avg IoU: 0.70790.7419
# Validation | Epoch [30/200], Avg Loss: 0.2073, Avg IoU: 0.6635
# Best mIoU: 0.712713531085423 at epoch 29
# ----------
# Epoch 31/200
# Training | Epoch [31/200], Avg Loss: 0.1553, Avg IoU: 0.72310.7758
# Validation | Epoch [31/200], Avg Loss: 0.1608, Avg IoU: 0.7029
# Best mIoU: 0.712713531085423 at epoch 29
# ----------
# Epoch 32/200
# Training | Epoch [32/200], Avg Loss: 0.1570, Avg IoU: 0.73280.7131
# Validation | Epoch [32/200], Avg Loss: 0.1610, Avg IoU: 0.7018
# Best mIoU: 0.712713531085423 at epoch 29
# ----------
# Epoch 33/200
# Training | Epoch [33/200], Avg Loss: 0.1556, Avg IoU: 0.72850.6893
# Validation | Epoch [33/200], Avg Loss: 0.1400, Avg IoU: 0.7421
# Save best model with mIoU = 0.7420936397143773
# ----------
# Epoch 34/200
# Training | Epoch [34/200], Avg Loss: 0.1509, Avg IoU: 0.72730.7258
# Validation | Epoch [34/200], Avg Loss: 0.1690, Avg IoU: 0.7022
# Best mIoU: 0.7420936397143773 at epoch 33
# ----------
# Epoch 35/200
# Training | Epoch [35/200], Avg Loss: 0.1525, Avg IoU: 0.72760.6899
# Validation | Epoch [35/200], Avg Loss: 0.1649, Avg IoU: 0.7023
# Best mIoU: 0.7420936397143773 at epoch 33
# ----------
# Epoch 36/200
# Training | Epoch [36/200], Avg Loss: 0.1541, Avg IoU: 0.73040.8388
# Validation | Epoch [36/200], Avg Loss: 0.1513, Avg IoU: 0.7130
# Best mIoU: 0.7420936397143773 at epoch 33
# ----------
# Epoch 37/200
# Training | Epoch [37/200], Avg Loss: 0.1552, Avg IoU: 0.72770.8549
# Validation | Epoch [37/200], Avg Loss: 0.1484, Avg IoU: 0.7389
# Best mIoU: 0.7420936397143773 at epoch 33
# ----------
# Epoch 38/200
# Training | Epoch [38/200], Avg Loss: 0.1438, Avg IoU: 0.73060.7734
# Validation | Epoch [38/200], Avg Loss: 0.1378, Avg IoU: 0.7363
# Best mIoU: 0.7420936397143773 at epoch 33
# ----------
# Epoch 39/200
# Training | Epoch [39/200], Avg Loss: 0.1439, Avg IoU: 0.73320.7186
# Validation | Epoch [39/200], Avg Loss: 0.1487, Avg IoU: 0.7160
# Best mIoU: 0.7420936397143773 at epoch 33
# ----------
# Epoch 40/200
# Training | Epoch [40/200], Avg Loss: 0.1440, Avg IoU: 0.73470.6826
# Validation | Epoch [40/200], Avg Loss: 0.1335, Avg IoU: 0.7386
# Best mIoU: 0.7420936397143773 at epoch 33
# ----------
# Epoch 41/200
# Training | Epoch [41/200], Avg Loss: 0.1390, Avg IoU: 0.73720.6296
# Validation | Epoch [41/200], Avg Loss: 0.1428, Avg IoU: 0.7393
# Best mIoU: 0.7420936397143773 at epoch 33
# ----------
# Epoch 42/200
# Training | Epoch [42/200], Avg Loss: 0.1394, Avg IoU: 0.73700.5126
# Validation | Epoch [42/200], Avg Loss: 0.1766, Avg IoU: 0.7043
# Best mIoU: 0.7420936397143773 at epoch 33
# ----------
# Epoch 43/200
# Training | Epoch [43/200], Avg Loss: 0.1486, Avg IoU: 0.73200.7514
# Validation | Epoch [43/200], Avg Loss: 0.1479, Avg IoU: 0.7136
# Best mIoU: 0.7420936397143773 at epoch 33
# ----------
# Epoch 44/200
# Training | Epoch [44/200], Avg Loss: 0.1489, Avg IoU: 0.73700.6729
# Validation | Epoch [44/200], Avg Loss: 0.1678, Avg IoU: 0.7010
# Best mIoU: 0.7420936397143773 at epoch 33
# ----------
# Epoch 45/200
# Training | Epoch [45/200], Avg Loss: 0.1262, Avg IoU: 0.74960.8485
# Validation | Epoch [45/200], Avg Loss: 0.1352, Avg IoU: 0.7275
# Best mIoU: 0.7420936397143773 at epoch 33
# ----------
# Epoch 46/200
# Training | Epoch [46/200], Avg Loss: 0.1182, Avg IoU: 0.75920.8355
# Validation | Epoch [46/200], Avg Loss: 0.1288, Avg IoU: 0.7556
# Save best model with mIoU = 0.75563531262534
# ----------
# Epoch 47/200
# Training | Epoch [47/200], Avg Loss: 0.1200, Avg IoU: 0.75810.6078
# Validation | Epoch [47/200], Avg Loss: 0.1424, Avg IoU: 0.7275
# Best mIoU: 0.75563531262534 at epoch 46
# ----------
# Epoch
# Best mIoU: 0.75563531262534 at epoch 46
# ----------
# Epoch 187/200
# Training | Epoch [187/200], Avg Loss: 0.1024, Avg IoU: 0.77470.7840
# Validation | Epoch [187/200], Avg Loss: 0.1338, Avg IoU: 0.7432
# Best mIoU: 0.75563531262534 at epoch 46
# ----------
# Epoch 188/200
# Training | Epoch [188/200], Avg Loss: 0.1038, Avg IoU: 0.76670.6401
# Validation | Epoch [188/200], Avg Loss: 0.1286, Avg IoU: 0.7520
# Best mIoU: 0.75563531262534 at epoch 46
# ----------
# Epoch 189/200
# Training | Epoch [189/200], Avg Loss: 0.1003, Avg IoU: 0.77460.9081
# Validation | Epoch [189/200], Avg Loss: 0.1356, Avg IoU: 0.7454
# Best mIoU: 0.75563531262534 at epoch 46
# ----------
# Epoch 190/200
# Training | Epoch [190/200], Avg Loss: 0.1036, Avg IoU: 0.77500.7328
# Validation | Epoch [190/200], Avg Loss: 0.1295, Avg IoU: 0.7482
# Best mIoU: 0.75563531262534 at epoch 46
# ----------
# Epoch 191/200
# Training | Epoch [191/200], Avg Loss: 0.1020, Avg IoU: 0.76700.5136
# Validation | Epoch [191/200], Avg Loss: 0.1439, Avg IoU: 0.7339
# Best mIoU: 0.75563531262534 at epoch 46
# ----------
# Epoch 192/200
# Training | Epoch [192/200], Avg Loss: 0.0994, Avg IoU: 0.77320.7174
# Validation | Epoch [192/200], Avg Loss: 0.1322, Avg IoU: 0.7474
# Best mIoU: 0.75563531262534 at epoch 46
# ----------
# Epoch 193/200
# Training | Epoch [193/200], Avg Loss: 0.1030, Avg IoU: 0.77800.8143
# Validation | Epoch [193/200], Avg Loss: 0.1422, Avg IoU: 0.7343
# Best mIoU: 0.75563531262534 at epoch 46
# ----------
# Epoch 194/200
# Training | Epoch [194/200], Avg Loss: 0.1010, Avg IoU: 0.77760.7520
# Validation | Epoch [194/200], Avg Loss: 0.1428, Avg IoU: 0.7347
# Best mIoU: 0.75563531262534 at epoch 46
# ----------
# Epoch 195/200
# Training | Epoch [195/200], Avg Loss: 0.0998, Avg IoU: 0.77250.6745
# Validation | Epoch [195/200], Avg Loss: 0.1438, Avg IoU: 0.7390
# Best mIoU: 0.75563531262534 at epoch 46
# ----------
# Epoch 196/200
# Training | Epoch [196/200], Avg Loss: 0.1003, Avg IoU: 0.76780.8052
# Validation | Epoch [196/200], Avg Loss: 0.1348, Avg IoU: 0.7445
# Best mIoU: 0.75563531262534 at epoch 46
# ----------
# Epoch 197/200
# Training | Epoch [197/200], Avg Loss: 0.1021, Avg IoU: 0.77140.6442
# Validation | Epoch [197/200], Avg Loss: 0.1434, Avg IoU: 0.7320
# Best mIoU: 0.75563531262534 at epoch 46
# ----------
# Epoch 198/200
# Training | Epoch [198/200], Avg Loss: 0.1002, Avg IoU: 0.77440.7835
# Validation | Epoch [198/200], Avg Loss: 0.1392, Avg IoU: 0.7351
# Best mIoU: 0.75563531262534 at epoch 46
# ----------
# Epoch 199/200
# Training | Epoch [199/200], Avg Loss: 0.1002, Avg IoU: 0.77500.7565
# Validation | Epoch [199/200], Avg Loss: 0.1342, Avg IoU: 0.7421
# Best mIoU: 0.75563531262534 at epoch 46
# ----------
# Epoch 200/200
# Training | Epoch [200/200], Avg Loss: 0.1025, Avg IoU: 0.77300.7709
# Validation | Epoch [200/200], Avg Loss: 0.1455, Avg IoU: 0.7341
# Best mIoU: 0.75563531262534 at epoch 46

# %%
# Step 18: Visualize Training and Validation Metrics
plt.figure(figsize=(10, 6))

# Plotting Training Loss
plt.plot(train_losses, label='Training Loss', color='blue')

# Plotting Validation Loss
plt.plot(val_losses, label='Validation Loss', color='orange')

# Plotting Training IoU
plt.plot(train_ious, label='Training IoU', color='green')

# Plotting Validation IoU
plt.plot(val_ious, label='Validation IoU', color='red')

plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.title('Training and Validation Metrics over Epochs')
plt.legend()
plt.grid(True)

# Show plot
plt.tight_layout()
plt.show()

# %%
# Step 19: Save Model Weights
torch.save(model.cpu().state_dict(), model_path)

# %%
# Step 20: Evaluate Model on Sample Images

# Set the model to evaluation mode
model.eval()

# Define the sample image names
names = ['00a3af90ab', '0a7e067255', '0a18b314fc']

# Load the sample images and masks
images = [Image.open(os.path.join(val_image_path, name+'.png')) for name in names]
masks = [Image.open(os.path.join(val_mask_path, name+'.png')) for name in names]

# Apply transformations to convert images to tensors
transforms = T.Compose([T.Grayscale(), T.ToTensor()])
x = torch.stack([transforms(image) for image in images])
y = torch.stack([transforms(mask) for mask in masks])

# Generate predictions using the model
outputs = model(x)
preds = torch.where(outputs<0., torch.zeros_like(outputs), torch.ones_like(outputs))
ious = get_iou_score(outputs, y)

# Visualize the sample images, ground truth masks, and model predictions
fig = plt.figure(figsize=(12, 9))
for i in range(len(names)):
    # Plot original image
    ax = fig.add_subplot(3, 4, i*4+1)
    plt.imshow(images[i])
    ax.set_title("Original Image")

    # Plot input tensor
    ax = fig.add_subplot(3, 4, i*4+2)
    ax.imshow(x[i].squeeze(), cmap="Greys")
    ax.set_title("Input Tensor (Grayscale)")

    # Plot ground truth mask
    ax = fig.add_subplot(3, 4, i*4+3)
    ax.imshow(y[i].squeeze(), cmap="Greens")
    ax.set_title("Ground Truth Mask")

    # Plot model prediction
    ax = fig.add_subplot(3, 4, i*4+4)
    ax.imshow(preds[i].squeeze(), cmap="OrRd")
    ax.set_title("Model Prediction\nIoU: " + str(round(ious[i].item(), 2)))

plt.tight_layout()
plt.show()

# %%
# Step 21: Make Predictions on Batch of Images
trainiter = iter(train_dataloader)
images, masks = next(trainiter)

outputs = model(images)
preds = torch.where(outputs<0., torch.zeros_like(outputs), torch.ones_like(outputs))
ious = get_iou_score(outputs, masks).numpy()

# %%
# Step 22: Visualize Predictions

# Define the number of images to display
num_images = 20

# Define the number of images per row and column
num_rows = 4
num_cols = 5

# Define the size of the overall figure
fig_width = 25
fig_height = 25

# Calculate the size of each subplot based on the number of rows and columns
sub_width = fig_width / num_cols
sub_height = fig_height / num_rows

# Create a figure and subplots with the specified size
fig, axs = plt.subplots(num_rows, num_cols, figsize=(fig_width, fig_height))

# Loop through each image
for i in range(num_images):
    # Extract the image, ground truth mask, prediction, and IoU
    image, mask, pred, iou = images[i], masks[i], preds[i], ious[i]

    # Get the corresponding axis for the subplot
    row = i // num_cols
    col = i % num_cols
    ax = axs[row, col]

    # Plot the original image
    ax.imshow(image.squeeze(), cmap="Greys")

    # Overlay the ground truth mask with green color
    ax.imshow(mask.squeeze(), alpha=0.5, cmap="Greens")

    # Overlay the model prediction with red color and reduced opacity
    ax.imshow(pred.squeeze(), alpha=0.3, cmap="OrRd")

    # Round the IoU score to two decimal places
    iou_rounded = round(iou, 2)

    # Set the title with the rounded IoU score
    # ax.set_title(f"IoU: {iou_rounded}", loc='left', fontsize=12)

    # Remove tick labels for better visualization
    ax.set_yticklabels([])
    ax.set_xticklabels([])

# Add legend for color representation
legend_elements = [plt.Line2D([0], [0], color='gray', lw=4, label='Original Image'),
                   plt.Line2D([0], [0], color='green', lw=4, label='Ground Truth Mask'),
                   plt.Line2D([0], [0], color='red', lw=4, label='Model Prediction')]

# Add legend to the figure
# plt.legend(handles=legend_elements, loc='upper center', bbox_to_anchor=(0.5, -0.05), fancybox=True, shadow=True, ncol=3, fontsize=12)

# Adjust layout to prevent overlapping
plt.tight_layout()

# Display the plot
plt.show()
